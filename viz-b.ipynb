# %% [markdown]
# # Data Visualization
# Top 10000 Popular Movies
# Renad Al-khlafat
# 27-10-2021

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## loading data from the CSV file for Top 10000 popular movie

# %%
movies_data = pd.read_csv("Top_10000_Popular_Movies.csv").head(20)
movies_data
# Out:
#     Unnamed: 0      id original_language  \
# 0            0  580489                en
# 1            1  335983                en
# 2            2  550988                en
# 3            3  772436                es
# 4            4  568620                en
# 5            5  639721                en
# 6            6  703771                en
# 7            7  610253                en
# 8            8  524369                en
# 9            9  589754                ru
# 10          10  843241                ja
# 11          11  637534                fr
# 12          12  681887                en
# 13          13  438631                en
# 14          14  566525                en
# 15          15  831405                en
# 16          16  436969                en
# 17          17  874948                tr
# 18          18  839436                en
# 19          19  385128                en
#
#                                 original_title  popularity release_date  \
# ...

# %%
sns.set_theme()
sns.pairplot(data=movies_data, hue="original_language")

# %% [markdown]
# ## Summary :
# 1. The English movies are most popular
# 2. There is a relationship between popularity and the avarage vote
